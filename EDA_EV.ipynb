# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('/Users/jagjeet/Downloads/Electric_Vehicle_Population_Data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130443 entries, 0 to 130442
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         130443 non-null  object
#  1   County                                             130440 non-null  object
#  2   City                                               130440 non-null  object
#  3   State                                              130443 non-null  object
#  4   Postal Code                                        130440 non-null  float64
#  5   Model Year                                         130443 non-null  int64
#  6   Make                                               130443 non-null  object
#  7   Model                                              130221 non-null  object
#  8   Electric Vehicle Type                              130443 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  130443 non-null  object
#  10  Electric Range                                     130443 non-null  int64
#  11  Base MSRP                                          130443 non-null  int64
#  12  Legislative District                               130138 non-null  float64
#  13  DOL Vehicle ID                                     130443 non-null  int64
#  14  Vehicle Location                                   130410 non-null  object
#  15  Electric Utility                                   130440 non-null  object
#  16  2020 Census Tract                                  130440 non-null  float64
# dtypes: float64(3), int64(4), object(10)
# memory usage: 16.9+ MB

# %%
df.shape
# Out:
# (130188, 12)

# %%
df.head(10)
# Out:
#    VIN (1-10)    County       City State  Postal Code  Model Year    Make  \
# 0  5YJXCAE26J    Yakima     Yakima    WA      98908.0        2018   TESLA
# 1  JHMZC5F37M    Kitsap    Poulsbo    WA      98370.0        2021   HONDA
# 2  5YJ3E1EB0K      King    Seattle    WA      98199.0        2019   TESLA
# 3  1N4AZ0CP5D      King    Seattle    WA      98119.0        2013  NISSAN
# 4  5YJSA1E21H  Thurston      Lacey    WA      98516.0        2017   TESLA
# 5  JHMZC5F1XJ  Thurston    Olympia    WA      98506.0        2018   HONDA
# 6  3FA6P0PU1G  Thurston   Tumwater    WA      98501.0        2016    FORD
# 7  WA1F2AFY8P  Thurston      Lacey    WA      98516.0        2023    AUDI
# 8  1FADP5CU0E  Thurston  Rochester    WA      98579.0        2014    FORD
# 9  5YJSA1CP1D    Kitsap  Bremerton    WA      98312.0        2013   TESLA
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL X          Battery Electric Vehicle (BEV)
# 1  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  MODEL 3          Battery Electric Vehicle (BEV)
# 3     LEAF          Battery Electric Vehicle (BEV)
# 4  MODEL S          Battery Electric Vehicle (BEV)
# 5  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 6   FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
# 7     Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)
# 8    C-MAX  Plug-in Hybrid Electric Vehicle (PHEV)
# 9  MODEL S          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
# 1           Clean Alternative Fuel Vehicle Eligible              47
# 2           Clean Alternative Fuel Vehicle Eligible             220
# 3           Clean Alternative Fuel Vehicle Eligible              75
# 4           Clean Alternative Fuel Vehicle Eligible             210
# 5           Clean Alternative Fuel Vehicle Eligible              47
# 6             Not eligible due to low battery range              19
# 7             Not eligible due to low battery range              23
# 8             Not eligible due to low battery range              19
# 9           Clean Alternative Fuel Vehicle Eligible             208
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  14.0       141151601
# 1          0                  23.0       171566447
# 2          0                  36.0         9426525
# 3          0                  36.0       211807760
# 4          0                  22.0       185810306
# 5          0                  22.0       153785726
# 6          0                  22.0       347508836
# 7          0                  22.0       227213871
# 8          0                  20.0       229811151
# 9      69900                  26.0       164768075
#
#               Vehicle Location                              Electric Utility  \
# 0  POINT (-120.56916 46.58514)                                    PACIFICORP
# 1  POINT (-122.64681 47.73689)                        PUGET SOUND ENERGY INC
# 2  POINT (-122.40092 47.65908)  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 3   POINT (-122.3684 47.64586)  CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 4  POINT (-122.75379 47.06316)                        PUGET SOUND ENERGY INC
# 5  POINT (-122.87741 47.05997)                        PUGET SOUND ENERGY INC
# 6  POINT (-122.89166 47.03956)                        PUGET SOUND ENERGY INC
# 7  POINT (-122.75379 47.06316)                        PUGET SOUND ENERGY INC
# 8  POINT (-123.08743 46.82175)                        PUGET SOUND ENERGY INC
# 9  POINT (-122.66122 47.56573)                        PUGET SOUND ENERGY INC
#
#    2020 Census Tract
# 0       5.307700e+10
# 1       5.303509e+10
# 2       5.303301e+10
# 3       5.303301e+10
# 4       5.306701e+10
# 5       5.306701e+10
# 6       5.306701e+10
# 7       5.306701e+10
# 8       5.306701e+10
# 9       5.303508e+10

# %%
df.drop(['VIN (1-10)','Postal Code','Base MSRP','Legislative District','DOL Vehicle ID','Electric Utility','2020 Census Tract'],axis=1,inplace=True)

# %%
df.head()
# Out:
#      County     City State  Model Year    Make    Model  \
# 0    Yakima   Yakima    WA        2018   TESLA  MODEL X
# 1    Kitsap  Poulsbo    WA        2021   HONDA  CLARITY
# 2      King  Seattle    WA        2019   TESLA  MODEL 3
# 3      King  Seattle    WA        2013  NISSAN     LEAF
# 4  Thurston    Lacey    WA        2017   TESLA  MODEL S
#
#                     Electric Vehicle Type  \
# 0          Battery Electric Vehicle (BEV)
# 1  Plug-in Hybrid Electric Vehicle (PHEV)
# 2          Battery Electric Vehicle (BEV)
# 3          Battery Electric Vehicle (BEV)
# 4          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
# 1           Clean Alternative Fuel Vehicle Eligible              47
# 2           Clean Alternative Fuel Vehicle Eligible             220
# 3           Clean Alternative Fuel Vehicle Eligible              75
# 4           Clean Alternative Fuel Vehicle Eligible             210
#
#               Vehicle Location
# 0  POINT (-120.56916 46.58514)
# 1  POINT (-122.64681 47.73689)
# 2  POINT (-122.40092 47.65908)
# 3   POINT (-122.3684 47.64586)
# 4  POINT (-122.75379 47.06316)

# %%
df.shape
# Out:
# (130443, 10)

# %%
df.isna().sum()
# Out:
# County                                                 3
# City                                                   3
# State                                                  0
# Model Year                                             0
# Make                                                   0
# Model                                                222
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Vehicle Location                                      33
# dtype: int64

# %%
df = df.dropna()

# %%
#Lets check from which county we have more entries from (Top 10)
counties = df.groupby('County').count().sort_values(by='City',ascending=False)['State'].index
values = df.groupby('County').count().sort_values(by='City',ascending=False)['State'].values

# %%
px.bar(x=list(counties)[:20],y=values[:20],labels={'x':"County Name",'y':"Number of Cars"},color=values[:20])

# %%
#lets see which company makes most of the electric vehicles
Companies = df.groupby('Make').count().sort_values(by='City',ascending=False)['City'].index
values = df.groupby('Make').count().sort_values(by='City',ascending=False)['City'].values


plt.figure(figsize=(10,5))
sns.barplot(x=list(Companies)[:20],y=values[:20],edgecolor='.3',palette='Set1')
plt.xticks(rotation='vertical')
plt.xlabel('Companies')
plt.ylabel('Count')
plt.show()

# %%
px.pie(names=list(Companies)[:20],values=values[:20],width=500,height=400)

# %% [raw]
# Tesla makes most ev

# %%
#Top 10 models in use

Models = df.groupby('Model').count().sort_values(by='City',ascending=False)['City'].index
values = df.groupby('Model').count().sort_values(by='City',ascending=False)['City'].values


plt.figure(figsize=(9,5))
sns.barplot(x=list(Models)[:10],y=values[:10],edgecolor='.2',palette='Set1')
plt.xticks(rotation='vertical')
plt.xlabel('Models')
plt.ylabel('Count')
plt.show()

# %%
#what are the most sold models per each company
#lets consider the top 20 companies
top_20_companies = list(Companies)[:20]

for i in top_20_companies:
    data = df[df['Make'] == i]
    data = data.groupby('Model').count().sort_values(by='City', ascending=False).index
    if len(data) >= 2:
        print('Top selling models for', i, 'are', 'rank 1', data[0], '&', 'rank 2', data[1])
    elif len(data) == 1:
        print('Top selling model for', i, 'is', 'rank 1', data[0])
    else:
        print('No data available for', i)
# Out:
# Top selling models for TESLA are rank 1 MODEL 3 & rank 2 MODEL Y
# Top selling models for NISSAN are rank 1 LEAF & rank 2 ARIYA
# Top selling models for CHEVROLET are rank 1 BOLT EV & rank 2 VOLT
# Top selling models for FORD are rank 1 MUSTANG MACH-E & rank 2 FUSION
# Top selling models for BMW are rank 1 I3 & rank 2 X5
# Top selling models for KIA are rank 1 NIRO & rank 2 EV6
# Top selling models for TOYOTA are rank 1 PRIUS PRIME & rank 2 RAV4 PRIME
# Top selling models for VOLKSWAGEN are rank 1 ID.4 & rank 2 E-GOLF
# Top selling models for VOLVO are rank 1 XC90 & rank 2 XC60
# Top selling models for AUDI are rank 1 E-TRON & rank 2 A3
# Top selling models for JEEP are rank 1 WRANGLER & rank 2 GRAND CHEROKEE
# Top selling models for HYUNDAI are rank 1 IONIQ 5 & rank 2 KONA ELECTRIC
# Top selling model for CHRYSLER is rank 1 PACIFICA
# Top selling models for RIVIAN are rank 1 R1T & rank 2 R1S
# Top selling models for PORSCHE are rank 1 TAYCAN & rank 2 CAYENNE
# Top selling model for FIAT is rank 1 500
# Top selling models for HONDA are rank 1 CLARITY & rank 2 ACCORD
# Top selling models for MINI are rank 1 HARDTOP & rank 2 COUNTRYMAN
# Top selling models for MERCEDES-BENZ are rank 1 GLC-CLASS & rank 2 EQS-CLASS SEDAN
# Top selling models for MITSUBISHI are rank 1 OUTLANDER & rank 2 I-MIEV

# %%
#Percentage of BEV vs PHEV

Vehicle_type = list(df.groupby('Electric Vehicle Type').count()['County'].index)
values = df.groupby('Electric Vehicle Type').count()['County'].values

px.pie(names=Vehicle_type,values=values,height=400)

# %%
#lets see whats the percentage of top 10 companies vehicles are BEV and PHEV

for index,i in enumerate(top_20_companies):
    data = df[df['Make']==i]
    labels = list(data.groupby('Electric Vehicle Type').count()['City'].index)
    values = list(data.groupby('Electric Vehicle Type').count()['City'].values)
    fig = px.pie(names=labels,values=values,width=700,height=400,title=str(i))
    fig.show()

# %%
#lets see the electric range difference between PHEV and BEV
plt.figure(figsize=(12,5))
sns.histplot(x = 'Electric Range',data=df,kde=True,hue='Electric Vehicle Type',palette='Set1')
# Out:
# <AxesSubplot: xlabel='Electric Range', ylabel='Count'>

# %%
#lets filter out top 5 companies as per each electric vehicle type

#PHEV

data_phev = df[df['Electric Vehicle Type']=='Plug-in Hybrid Electric Vehicle (PHEV)']
companies=list(data_phev.groupby('Make').count().sort_values(by='City',ascending=False)['City'].index)[:5]
data_phev['phe'] = data_phev['Make'].apply(lambda x:1 if x in companies else 0 )
data_phev = data_phev[data_phev['phe']==1]

plt.figure(figsize=(10,5))
sns.kdeplot(x='Electric Range',hue='Make',data=data_phev)
# Out:
# /var/folders/db/trptpqj11p56c79tjk4tbtk80000gq/T/ipykernel_2742/3654208490.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <AxesSubplot: xlabel='Electric Range', ylabel='Density'>

# %%
#BEV


data_bev = df[df['Electric Vehicle Type']!='Plug-in Hybrid Electric Vehicle (PHEV)']
companies=list(data_bev.groupby('Make').count().sort_values(by='City',ascending=False)['City'].index)[:5]
data_bev['bev'] = data_bev['Make'].apply(lambda x:1 if x in companies else 0 )
data_bev = data_bev[data_bev['bev']==1]

plt.figure(figsize=(10,5))
sns.kdeplot(x='Electric Range',hue='Make',data=data_bev)
# Out:
# /var/folders/db/trptpqj11p56c79tjk4tbtk80000gq/T/ipykernel_2742/2626622709.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <AxesSubplot: xlabel='Electric Range', ylabel='Density'>

# %%
#BEV_Tesla_Models


data_bev_tesla = df[df['Make']=='TESLA']
Model=list(data_bev_tesla.groupby('Model').count().sort_values(by='Electric Range',ascending=False)['Electric Range'].index)[:5]
data_bev_tesla['bev'] = data_bev_tesla['Model'].apply(lambda x:1 if x in Model else 0 )
data_bev_tesla = data_bev_tesla[data_bev_tesla['bev']==1]

plt.figure(figsize=(10,5))
sns.kdeplot(x='Electric Range',hue='Model',data=data_bev_tesla)
# Out:
# /var/folders/db/trptpqj11p56c79tjk4tbtk80000gq/T/ipykernel_2742/2011377322.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <AxesSubplot: xlabel='Electric Range', ylabel='Density'>

# %%
#if we remove zero ranges we can see CHEVROLET, TESLA AND KIA offering high ranges

# %%
#lets see top20 most sold cars and top20 most range giving vehicles and check if there is any correlation
top_10_vehicles = list(df.groupby('Model').count().sort_values(by='City',ascending=False)['City'].index)[:10]
top_10_range =  df.sort_values(by='Electric Range',ascending=False)['Model'].unique()[:10]
top_10_vehicles
# Out:
# ['MODEL 3',
#  'MODEL Y',
#  'LEAF',
#  'MODEL S',
#  'BOLT EV',
#  'VOLT',
#  'MODEL X',
#  'NIRO',
#  'PRIUS PRIME',
#  'ID.4']

# %%
top_10_range
# Out:
# array(['MODEL S', 'MODEL 3', 'MODEL X', 'MODEL Y', 'BOLT EV', 'KONA',
#        'ROADSTER', 'NIRO', 'I-PACE', 'PS2'], dtype=object)

# %%
#6 out of top 10 most selling ones are in the top_10 electric range vehicles so range can be a reason of their sales

# %%
#Number of models of company for each year for last 10 years
#lets consider top_20 companies only

data = df.copy()
data['top_20'] = data['Make'].apply(lambda x:1 if x in top_20_companies else 0)
data = data[data['top_20']==1]
data = data[data['Model Year']>=2011]
plt.figure(figsize=(12,5))
sns.countplot(x = 'Model Year',hue='Make',data=data, palette="Set1")
# Out:
# <AxesSubplot: xlabel='Model Year', ylabel='count'>

# %%
#earlier NISSAN and CHEVY used to have hold of the market then TESLA took over it from 2018 till date

# %%
#if we study an individual company TESLA
#1.which state is having more number of TESLA vehicles
#2.Model of which year is in use the most from TESLA

data_TESLA = df[df['Make']=='TESLA']
top_10_states_TESLA = list(data_TESLA.groupby('State').count().sort_values(by='City',ascending=False)['City'].index)[:10]
values = list(data_TESLA.groupby('State').count().sort_values(by='City',ascending=False)['City'].values)[:10]

# %%
sns.barplot(x = top_10_states_TESLA,y=values,edgecolor='.2')
# Out:
# <AxesSubplot: >

# %%
data_TESLA = df[df['Make']=='TESLA']
top_10_model = list(data_TESLA.groupby('State').count().sort_values(by='City',ascending=False)[''].index)[:10]
values = list(data_TESLA.groupby('State').count().sort_values(by='City',ascending=False)['City'].values)[:10]

# %%
#Most of the Tesla vehicles are from 'WA' state

# %%
plt.figure(figsize=(10,6))
top_10_year_TESLA = list(data_TESLA.groupby('Model Year').count().sort_values(by='City',ascending=False)['City'].index)[:10]
values = list(data_TESLA.groupby('Model Year').count().sort_values(by='City',ascending=False)['City'].values)[:10]
sns.barplot(x = top_10_year_TESLA,y=values,edgecolor='.2')
# Out:
# <AxesSubplot: >

# %%
#most models are from 2022 which are sold by tesla

# %%
locations = list(df.groupby('Vehicle Location').count()['County'].index)
values = list(df.groupby('Vehicle Location').count()['County'].values)
Location_data = pd.DataFrame({'Locations':locations,'Count':values})
Location_data['Lattitude'] = Location_data['Locations'].apply(lambda x:float(x.split(' ')[1][1:]))
Location_data['Longitude'] = Location_data['Locations'].apply(lambda x:float(x.split(' ')[2][:-1]))

plt.figure(figsize=(10,5))
plt.scatter(x = Location_data['Lattitude'],y = Location_data['Longitude'],s=Location_data['Count'])
plt.xlim(-130,-60)
plt.ylim(20,60)
# Out:
# (20.0, 60.0)

# %%
#Most data points are from 'WA' state

# %%
df['Lattitude'] = df['Vehicle Location'].apply(lambda x:float(x.split(' ')[1][1:]))
df['Longitude'] = df['Vehicle Location'].apply(lambda x:float(x.split(' ')[2][:-1]))

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x = 'Lattitude',y = 'Longitude',data=df,hue='Clean Alternative Fuel Vehicle (CAFV) Eligibility',palette='Set2')
plt.xlim(-130,-60)
plt.ylim(20,50)
# Out:
# (20.0, 50.0)

# %%
#density is more at certain regions of the map and distribution of CAFV can be seen

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x = 'Lattitude',y = 'Longitude',data=df,hue='Electric Vehicle Type',palette='Set1')
plt.xlim(-130,-60)
plt.ylim(20,50)
# Out:
# (20.0, 50.0)

# %%
states = list(df.groupby('State').count().sort_values(by='City',ascending=False)['City'].index)
values = df.groupby('State').count().sort_values(by='City',ascending=False)['City'].values

# %%
data = pd.DataFrame(df.groupby('State').count().sort_values(by='City',ascending=False)['City'])

# %%
data = data.reset_index()

# %%
data.columns = ['State','Count']

# %%
fig = px.choropleth(data,
                    locations='State', 
                    locationmode="USA-states", 
                    color='Count',
                    color_continuous_scale="greens", 
                    scope="usa")

fig.show()

# %%
data_phev_Tesla.head()
# Out:
#       County       City State  Model Year   Make    Model  \
# 0     Yakima     Yakima    WA        2018  TESLA  MODEL X
# 2       King    Seattle    WA        2019  TESLA  MODEL 3
# 4   Thurston      Lacey    WA        2017  TESLA  MODEL S
# 9     Kitsap  Bremerton    WA        2013  TESLA  MODEL S
# 11    Yakima     Yakima    WA        2022  TESLA  MODEL Y
#
#              Electric Vehicle Type  \
# 0   Battery Electric Vehicle (BEV)
# 2   Battery Electric Vehicle (BEV)
# 4   Battery Electric Vehicle (BEV)
# 9   Battery Electric Vehicle (BEV)
# 11  Battery Electric Vehicle (BEV)
#
#     Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0             Clean Alternative Fuel Vehicle Eligible             238
# 2             Clean Alternative Fuel Vehicle Eligible             220
# 4             Clean Alternative Fuel Vehicle Eligible             210
# 9             Clean Alternative Fuel Vehicle Eligible             208
# 11  Eligibility unknown as battery range has not b...               0
#
#                Vehicle Location  Lattitude  Longitude
# 0   POINT (-120.56916 46.58514) -120.56916   46.58514
# 2   POINT (-122.40092 47.65908) -122.40092   47.65908
# 4   POINT (-122.75379 47.06316) -122.75379   47.06316
# 9   POINT (-122.66122 47.56573) -122.66122   47.56573
# 11  POINT (-120.56916 46.58514) -120.56916   46.58514
